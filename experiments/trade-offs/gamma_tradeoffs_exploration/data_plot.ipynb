# %%
import matplotlib.pyplot as plt

# 初始化扰动比例的列表
alter_percentages = [20, 40, 60, 80, 100]


z_scores_ratio_1_3 = [23.866, 15.866, 9.6, 3.333, -2.666]
z_scores_ratio_1_2 = [19.350, 14.696, 6.491, 2.327, -3.061]
z_scores_ratio_1_1 = [13.279, 7.505, 5.427, -0.346, -4.156]
z_scores_ratio_2_1 = [8.818, 4.654, 0.612, -1.347, -6.368]
z_scores_ratio_3_1 = [6.266, 2.533, -2.0, -3.733, -5.733]

# 初始化各个比例对应的z-score的列表
# z_scores_ratio_1_3 = [30.0, 23.866, 15.866, 9.6, 3.333, -2.666]
# z_scores_ratio_1_2 = [24.494, 19.350, 14.696, 6.491, 2.327, -3.061]
# z_scores_ratio_1_1 = [17.320, 13.279, 7.505, 5.427, -0.346, -4.156]
# z_scores_ratio_2_1 = [12.247, 8.818, 4.654, 0.612, -1.347, -6.368]
# z_scores_ratio_3_1 = [10.0, 6.266, 2.533, -2.0, -3.733, -5.733]


colors = ['#afd9e6', '#88ceeb', '#709dee', '#577ae4', '#0a0a8f']

# 执行画图操作
plt.figure(figsize=(8, 6))

plt.plot(alter_percentages, z_scores_ratio_1_3, marker='o', markersize=15, markeredgewidth=3, color=colors[0],linewidth=3, markerfacecolor='none', label='γ: 0.25')
plt.plot(alter_percentages, z_scores_ratio_1_2, marker='v', markersize=15, markeredgewidth=3, color=colors[1],linewidth=3, markerfacecolor='none', label='γ: 0.33')
plt.plot(alter_percentages, z_scores_ratio_1_1, marker='^', markersize=15, markeredgewidth=3, color=colors[2],linewidth=3, markerfacecolor='none', label='γ: 0.50')
plt.plot(alter_percentages, z_scores_ratio_2_1, marker='s', markersize=15, markeredgewidth=3, color=colors[3],linewidth=3, markerfacecolor='none', label='γ: 0.67')
plt.plot(alter_percentages, z_scores_ratio_3_1, marker='d', markersize=15, markeredgewidth=3, color=colors[4],linewidth=3, markerfacecolor='none', label='γ: 0.75')


# Increased font size and bolded axis names
plt.xlabel('Alter Proportion β (%)', fontsize=20, fontweight='bold')
plt.ylabel('Z-scores', fontsize=20, fontweight='bold')

# Set the ticks on the x-axis and make them larger
plt.xticks([20, 40, 60, 80, 100], fontsize=20)
plt.yticks(fontsize=20)  

plt.legend(fontsize=20)  # 或者使用具体数值，例如 fontsize=14

# plt.legend()

# plt.show()
plt.savefig("plot/z_gamma.pdf")

# %%
import matplotlib.pyplot as plt

# 你需要初始化扰动比例
alter_percentages = [20, 40, 60, 80, 100]

# 初始化各个比例对应的分类准确度
accuracy_ratio_1_3 = [0.92833, 0.92, 0.89833, 0.89, 0.88333]
accuracy_ratio_1_2 = [0.93, 0.92, 0.90, 0.89333, 0.88333]
accuracy_ratio_1_1 = [0.93, 0.92, 0.89833, 0.89, 0.88333]
accuracy_ratio_2_1 = [0.92833, 0.91833, 0.895, 0.89166, 0.885]
accuracy_ratio_3_1 = [0.92833, 0.92, 0.895, 0.89166, 0.88333]

colors = ['#afd9e6', '#88ceeb', '#709dee', '#577ae4', '#0a0a8f']

# 执行画图操作
plt.figure(figsize=(8, 6))

plt.plot(alter_percentages, accuracy_ratio_1_3, marker='o', markersize=15, markeredgewidth=3, color=colors[0],linewidth=3, markerfacecolor='none', label='γ: 0.25')
plt.plot(alter_percentages, accuracy_ratio_1_2, marker='v', markersize=15, markeredgewidth=3, color=colors[1],linewidth=3, markerfacecolor='none', label='γ: 0.33')
plt.plot(alter_percentages, accuracy_ratio_1_1, marker='^', markersize=15, markeredgewidth=3, color=colors[2],linewidth=3, markerfacecolor='none', label='γ: 0.50')
plt.plot(alter_percentages, accuracy_ratio_2_1, marker='s', markersize=15, markeredgewidth=3, color=colors[3],linewidth=3, markerfacecolor='none', label='γ: 0.67')
plt.plot(alter_percentages, accuracy_ratio_3_1, marker='d', markersize=15, markeredgewidth=3, color=colors[4],linewidth=3, markerfacecolor='none', label='γ: 0.75')


# Increased font size and bolded axis names
plt.xlabel('Alter Proportion β (%)', fontsize=20, fontweight='bold')
plt.ylabel('Classification Accuracy', fontsize=20, fontweight='bold')

# Set the ticks on the x-axis and make them larger
plt.xticks([20, 40, 60, 80, 100], fontsize=20)
plt.yticks(fontsize=20)  

plt.legend(fontsize=20)  # 或者使用具体数值，例如 fontsize=14

# plt.legend()

# plt.show()
plt.savefig("plot/a_gamma.pdf")

# %%
import numpy as np
import pandas as pd

# 加载索引列表
with open('tabularmark_index.txt', 'r') as f:
    indices = [int(line.strip()) for line in f.readlines()]

# file_paths = [
#     "/home/zhengyihao/TabularMark/classfication_task/normal_distribution/synthetic_dataset_labeled.csv",
#     "/home/zhengyihao/TabularMark/classfication_task/normal_distribution/watermarked_synthetic_dataset_labeled.csv",
#     "/home/zhengyihao/dataset/normal_distribution/tabularmark_alter20.data.csv",
#     "/home/zhengyihao/dataset/normal_distribution/tabularmark_alter40.data.csv",
#     "/home/zhengyihao/dataset/normal_distribution/tabularmark_alter60.data.csv",
#     "/home/zhengyihao/dataset/normal_distribution/tabularmark_alter80.data.csv",
#     "/home/zhengyihao/dataset/normal_distribution/tabularmark_alter100.data.csv"
# ]

file_paths = [
    "/home/zhengyihao/TabularMark/classfication_task/normal_distribution/synthetic_dataset_labeled.csv",
    "/home/zhengyihao/dataset/normal_distribution/variation_z/watermarked_synthetic_dataset_labeled_1_3.csv",
    "/home/zhengyihao/dataset/normal_distribution/variation_z/watermarked_synthetic_dataset_labeled_1_2.csv",
    "/home/zhengyihao/dataset/normal_distribution/variation_z/watermarked_synthetic_dataset_labeled_1_1.csv",
    "/home/zhengyihao/dataset/normal_distribution/variation_z/watermarked_synthetic_dataset_labeled_2_1.csv",
    "/home/zhengyihao/dataset/normal_distribution/variation_z/watermarked_synthetic_dataset_labeled_3_1.csv",
    # "/home/zhengyihao/dataset/normal_distribution/variation_z/watermarked_synthetic_dataset_labeled_1_50.csv"
]

# 整理索引
indices = np.array(indices)

# 为每个路径创建一个放置结果的字典
results = {path: {} for path in file_paths}

# 加载并处理每个文件
for path in file_paths:
    data = pd.read_csv(path)
    # 获取给定的indices对应的dimension_0列的值
    # values = data.loc[indices, "dimension_0"]
    values = data["dimension_0"]
    # print(np.array(values))
    # 计算均值和方差然后保存到对应的路径的字典中
    results[path]["mean"] = np.mean(values)
    results[path]["std"] = np.std(values)

# 打印结果
for path, sub_dict in results.items():
    print(f"For file '{path}', the mean and STD of 'dimension_0' for the given indices are {sub_dict['mean']} and {sub_dict['std']}, respectively.")
# Out:
# For file '/home/zhengyihao/TabularMark/classfication_task/normal_distribution/synthetic_dataset_labeled.csv', the mean and STD of 'dimension_0' for the given indices are 1.6554211495729656 and 19.84830205811873, respectively.
# For file '/home/zhengyihao/dataset/normal_distribution/variation_z/watermarked_synthetic_dataset_labeled_1_3.csv', the mean and STD of 'dimension_0' for the given indices are 1.5502541751111558 and 20.82927996898398, respectively.
# For file '/home/zhengyihao/dataset/normal_distribution/variation_z/watermarked_synthetic_dataset_labeled_1_2.csv', the mean and STD of 'dimension_0' for the given indices are 1.5848222809208343 and 20.926984334416048, respectively.
# For file '/home/zhengyihao/dataset/normal_distribution/variation_z/watermarked_synthetic_dataset_labeled_1_1.csv', the mean and STD of 'dimension_0' for the given indices are 1.8612792375850904 and 20.700719634167847, respectively.
# ...
