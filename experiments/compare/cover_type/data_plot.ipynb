# %%
# show dataset label distribution

import pandas as pd
from matplotlib import pyplot as plt

# 加载数据
data = pd.read_csv('/home/zhengyihao/dataset/covertype/covtype_with_key.subset.data')

print(data.shape[0])

# 使用 pandas 的 value_counts 函数计算每种 Cover_Type 的数量
cover_type_counts = data['Cover_Type'].value_counts()

# 画出条形图
cover_type_counts.plot(kind='bar')

# 设置标题和轴标签
plt.title('Distribution of Cover_Type')
plt.xlabel('Cover_Type')
plt.ylabel('Count')

# 显示图形
plt.savefig("/home/zhengyihao/TabularMark/classfication_task/plot/label_distribution")
# Out:
# 14000
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 23
#      20 plt.ylabel('Count')
#      22 # 显示图形
# ---> 23 plt.savefig("/home/zhengyihao/TabularMark/classfication_task/plot/label_distribution")
#
# File ~/anaconda3/envs/watermark/lib/python3.10/site-packages/matplotlib/pyplot.py:1119, in savefig(*args, **kwargs)
#    1116 fig = gcf()
#    1117 # savefig default implementation has no return, so mypy is unhappy
#    1118 # presumably this is here because subclasses can return?
# -> 1119 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1120 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1121 return res
#
# File ~/anaconda3/envs/watermark/lib/python3.10/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
# ...

# %%
import matplotlib.pyplot as plt
import json
import numpy as np

# 增大全局字体大小并设置粗体
plt.rcParams['font.size'] = 25


# colors = ['#afd9e6', '#88ceeb', '#709dee', '#577ae4', '#0a0a8f']
colors = ['#88ceeb', '#709dee', '#0a0a8f', '#577ae4']

# 原始数据
data  = [
    {"1": 0.7016666666666667, "2": 0.6311858076563959, "3": 0.7644991212653779, "4": 0.9361370716510903, "5": 0.8533747090768038, "6": 0.7809847198641766, "7": 0.9209677419354839, "algorithm": "Original"},
    {"1": 0.6926333615580017, "2": 0.6406533575317604, "3": 0.7716814159292036, "4": 0.9324009324009325, "5": 0.84472049689441, "6": 0.8044217687074829, "7": 0.9255663430420712, "algorithm": "TabulaMark"},
    {"1": 0.5739036275040607, "2": 0.0, "3": 0.44472049689440996, "4": 0.9134687735139202, "5": 0.6829765545361876, "6": 0.01418439716312057, "7": 0.5685483870967741, "algorithm": "HistMark"},
    {"1": 0.6713043478260871, "2": 0.5907808090310442, "3": 0.6361867704280155, "4": 0.8706896551724138, "5": 0.7988338192419825, "6": 0.7337380745880312, "7": 0.9210950080515298, "algorithm": "SemMark"}
]


# 可视化
plt.figure(figsize=[8,6])

# 准备不同的标记，为每个算法使用不同的标记
markers = ['o', 'v', '^', 's', 'd']

# 遍历数据，对每个算法绘制一条线，并为每条线指定不同的标记
for i, algorithm_data in enumerate(data):
    # 获取标签名（算法名）
    label = algorithm_data['algorithm']

    # 获取f1-scores，注意只获取了类标签为字符串 "1" 到 "7" 的值
    f1_scores = [algorithm_data[str(j)] for j in range(1,8)]
    
    # 绘制线条，指定不同的标记
    plt.plot(range(1, 8), f1_scores, color = colors[i], marker=markers[i], label=label, linewidth=3, markersize=15,markerfacecolor='none', markeredgewidth=3)  # linewidth和markersize调整线条和标记的大小

plt.xlabel('Category')    # X轴标签
plt.ylabel('F1-score')    # Y轴标签
# plt.title('F1-score per category for different watermarking')  # 图标题

plt.xticks(range(1, 8), fontsize=20, weight='normal')
plt.yticks(fontsize=20, weight='normal')  

plt.legend(prop={'weight':'normal', 'size':20})  # 显示图例
# plt.show()  # 显示图像
plt.savefig("/home/zhengyihao/TabularMark/classfication_task/cover_type/plot/f1_distribution.pdf")

# %%
import matplotlib.pyplot as plt
import numpy as np

# 增大全局字体大小并设置粗体
plt.rcParams['font.size'] = 25
# plt.rcParams['font.weight'] = 'bold'
# plt.rcParams['axes.labelweight'] = 'bold'
# plt.rcParams['axes.titleweight'] = 'bold'
# plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Blues(np.linspace(1, 0.2, 4)))  # 设置颜色循环为蓝色调

# 数据整理
tabularmark_data = [0.0, 5.0, 12.5, 19.5, 25.5, 28.75, 36.25, 37.25, 43.75, 49.25, 61.0]
histogrammark_data = [17.75, 19.0, 21.0, 21.0, 27.0, 30.25, 34.0, 35.5, 39.75, 46.0, 50.75]
semanticmark_data = [18.0, 20.0, 24.0, 24.5, 27.0, 28.5, 32.0, 35.75, 35.0, 41.0, 45.75]


# 定义x轴数据
x_data = range(0, 110, 10)

# 配置图形大小
plt.figure(figsize=[8,6])

# 准备不同的标记，为每个算法使用不同的标记
markers = [ 'o', 'v', '^']

# 绘制折线图
plt.plot(x_data, tabularmark_data, marker=markers[0], label='TabularMark' ,linewidth=3, markersize=15,markerfacecolor='none', markeredgewidth=3)
plt.plot(x_data, histogrammark_data, marker=markers[1], label='HistMark',linewidth=3, markersize=15,markerfacecolor='none', markeredgewidth=3)
plt.plot(x_data, semanticmark_data, marker=markers[2], label='SemMark', linewidth=3, markersize=15,markerfacecolor='none', markeredgewidth=3)

# 设置x轴范围为0-70
plt.xlim(0, 70)
plt.ylim(0, 45)

# 标识x轴和y轴
plt.xlabel('Alteration Proportion β (%)', fontsize=20) 
plt.ylabel('MP (%)')

# 图表标题
# plt.title('Mismatch Percentage for Different Algorithms')
plt.xticks(fontsize=20, weight='normal')
plt.yticks(fontsize=20, weight='normal')  

# 显示图例
plt.legend(prop={'weight':'normal', 'size':20})  # 显示图例

# 保存图片而不展示
plt.savefig("/home/zhengyihao/TabularMark/classfication_task/cover_type/plot/mismatch_distribution.pdf")
